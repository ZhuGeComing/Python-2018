# %%
import requests
sk = '2p9LAgzn9oGVacjjHT4GAoXg38YWrvv3'
url = 'http://api.map.baidu.com/place/v2/search?query=西北工业大学（长安校区）&region=西安&output=json&ak=' +  sk
# url = 'http://api.map.baidu.com/place/v2/search?query=银行&location=34.757921,113.023149&radius=200&output=json&ak=' + sk
# uid = 'a4d0e6bc575a42af28201a1c'
# url = 'http://api.map.baidu.com/place/v2/detail?uid=' + uid + '&output=json&scope=2&ak=' + sk
# url = 'http://api.map.baidu.com/place/v2/suggestion?query=森海星苑&region=巩义&city_limit=true&output=json&ak=' + sk
# url = 'http://api.map.baidu.com/geocoder/v2/?address=西北工业大学（长安校区）&output=json&ak='+sk
# url = 'http://api.map.baidu.com/direction/v2/driving?origin=34.75792412506873,113.02315091338535&destination=34.758379,113.023587&output=json&ak='+sk
# url = 'http://api.map.baidu.com/parking/search?location=113.02315091338535,34.75792412506873&coordtype=bd09ll&ak=' + sk
print(requests.get(url).text)
# Out:
# {
#     "status":0,
#     "message":"ok",
#     "results":[
#         {
#             "name":"西北工业大学长安校区",
#             "location":{
#                 "lat":34.039191,
#                 "lng":108.771709
#             },
#             "address":"陕西省西安长安区东祥路1号",
#             "province":"陕西省",
#             "city":"西安市",
#             "area":"长安区",
#             "detail":1,
#             "uid":"ac5e594a4e2716d31d580047"
#         },
#         {
#             "name":"西北工业大学长安校区-东一门",
#             "location":{
#                 "lat":34.039708,
#                 "lng":108.776352
#             },
#             "address":"东祥路1号西北工业大学长安校区",
#             "province":"陕西省",
#             "city":"西安市",
#             "area":"长安区",
#             "detail":1,
#             "uid":"6cc015abcff6520702ec015e"
#         },
#         {
#             "name":"西北工业大学长安校区-管理学院",
#             "location":{
#                 "lat":34.037519,
#                 "lng":108.774019
#             },
# ...
